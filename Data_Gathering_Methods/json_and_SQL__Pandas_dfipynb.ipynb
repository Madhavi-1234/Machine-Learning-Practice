# %% [markdown]
# <a href="https://colab.research.google.com/github/Madhavi-1234/Machine-Learning-Practice/blob/main/json_and_SQL__Pandas_dfipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import zipfile

zip_path = "/content/train.json.zip"   # Change this to your zip file name

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall("/content/data")

# %%
import os

os.listdir("/content/data")
# Out:
# ['train.json']

# %% [markdown]
# ## Reading a json file (ater unzip)

# %%
df= pd.read_json('/content/data/train.json')

# %%
df.head()
# Out:
#       id      cuisine                                        ingredients
# 0  10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1  25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2  20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3  22213       indian                [water, vegetable oil, wheat, salt]
# 4  13162       indian  [black pepper, shallots, cornflour, cayenne pe...

# %% [markdown]
# ### Working with SQL
#
# some steps are here when you are done with XAMMP and phpMyAdmin (after loading files)
#
#
# 1. install librray called  mysql connector
#
# 2. connect the database
# 3.

# %%
# !pip install mysql.connector
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 100.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for mysql.connector: filename=mysql_connector-2.2.9-cp312-cp312-linux_x86_64.whl size=247950 sha256=4561379df36b392a2ba774d4ec9f95062d1f6d815776ce8949f7d1c352bbdc1d
#   Stored in directory: /root/.cache/pip/wheels/03/17/fa/d7604c72dd3dd6d3eb3d249abf36cc532c9a9b4354b8f1bc4f
# Successfully built mysql.connector
# ...

# %%
conn= mysql.connector.connect(host= "localhost", user ='root',password= " ", database='database_name')

# %%
### to convert into pandas
## function need one sql query + the conn variable( connector)
## it will automatically convert this into pandas dataframe

pd.read_sql_query('SELECT * FROM  city / or  any SQL Query', conn)

# %% [markdown]
# ## **DOCUMNETATION **exploration ragrding
# **json and **SQL can help alot to get  better understanding of all the import Fundamentals
